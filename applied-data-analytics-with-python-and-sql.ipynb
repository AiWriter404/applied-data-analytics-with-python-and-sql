# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %% [markdown]
# # **1- Identifiers in Pyhton**

# %%
# Defining Variables (Identifiers) (Variables)
age=25
name="alice"
#Defining a function (Identifiers)
def greet():
    print("Hello World")
# Calling a function
greet()

# %% [markdown]
# 1. Must Begin with letters (a to z) or (A to Z) or underscore(_)
# 2. cannot start with a number
# 3. can only contains alphanumeric characters(letter, numbers and underscores)
# 4. Case sensitive : Name and name are two different Identifiers .
# 5. cannot use python keywords as identifiers (as like for if else etc)

# %%
# Valid Identifiers 
my_variable=10
_name="Sarim"
age=30
# invalid Identifiers (these will raise error)
2nd_Variable=100 # its start with a number (wrong)
my-variable=30 # contains a hyphen (wrong)
def="Keyword" # uses a python keyword (wrong)
# Out:
#   File "/tmp/ipykernel_103/1867997961.py", line 6
#     2nd_Variable=100 # its start with a number (wrong)
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # **2- Literals in Python**

# %%
# Srting (single and double code string)
greeting='Hello World'
name="Umar"
print('single qoute string',greeting)
print("double qoute string", name)
# Out:
# single qoute string Hello World
# double qoute string Umar

# %%
# Multiline String
multiline_text='''This is a multinline string 
in python'''
print("Multiline String",multiline_text)
# Out:
# Multiline String This is a multinline string
# in python

# %%
# Escap Characters
escaped_string="He said \"He has not complete his Doctor Degree!\""
print("Escaped string:", escaped_string)
# Out:
# Escaped string: He said "He has not complete his Doctor Degree!"

# %%
# Boolean Leterals
is_python_fun=True
is_raining=False
print("Boolean Literals",is_python_fun,is_raining)
# Out:
# Boolean Literals True False

# %%
# None Literals 
nothing_here=None
print("None Literals:", nothing_here)
# Out:
# None Literals: None

# %%
# list literals
my_list=[1,2,3,4,5,"apple","banana","orange","mango","kewe"]
print("List Literals",my_list)
# Out:
# List Literals [1, 2, 3, 4, 5, 'apple', 'banana', 'orange', 'mango', 'kewe']

# %%
# Tuple Literals
my_tuple=(10,20,30)
print("Tuple Literals:",my_tuple)
# Out:
# Tuple Literals: (10, 20, 30)

# %%
# Dictionary Literals
my_dict={"name":"Umar","age":25}
print("Dictionary Literals:",my_dict)
# Out:
# Dictionary Literals: {'name': 'Umar', 'age': 25}

# %%
# Set Literals 
my_set= {1,2,3,4,5,}
print("Set Literals:",my_set)
# Out:
# Set Literals: {1, 2, 3, 4, 5}

# %% [markdown]
# # **3- Operators in Python**

# %%
# Arethmatic Operators
a=10
b=3
# Addition
print("addition:",a+b)

# Substraction
print("Substraction:",a-b)

# Multiplication

print("Multiplication:",a*b)

# Division

print("Division",a/b)

# Floor Division (Remove decimal part)

print("Floor Division:",a//b)

# Modulus (Remainder)

print("Modulus:",a%b)

# Exponentiation (Power)

print("Exponentiation:",a**b)
# Out:
# addition: 13
# Substraction: 7
# Multiplication: 30
# Division 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponentiation: 1000

# %%
# Comparison Operators

x=5
y=10

# Equal to

print("Equal to :", x==y)

# Not Equal 

print("Not Equal:", x!=y)

# Greater Than

print("Greater Than:",x > y)

# Greater than or Equal to 

print("Greater Than Or Equal to:",x >= y)

# Less Than or Equal to 

print("Less Than And Equal to :", x <= y)
# Out:
# Equal to : False
# Not Equal: True
# Greater Than: False
# Greater Than Or Equal to: False
# Less Than And Equal to : True

# %%
# Assignment Operators

# Add  and assign

x+=5

print("x after +=5:", x)

# Substract and Assign

x -=3
print("x after -=3:",x)

# Multiply and Assign

x *=2
print("x after *=2:",x)

# Divide and Assign

x /=4
print("x after /=4:", x)
# Out:
# x after +=5: 10
# x after -=3: 7
# x after *=2: 14
# x after /=4: 3.5

# %%
# Logical Operators
a = True
b = False

# Logical AND

print("a AND b:",a and b)

# Logical OR

print("a OR b:",a or b)

# Logical NOT

print("NOT a:", not a)
# Out:
# a AND b: False
# a OR b: True
# NOT a: False

# %%
# Bitwise operators
x = 5  # 0b0101 (binary)
y = 3  # 0b0011 (binary)

# AND
print("x & y (AND):", x & y)  # Result: 1 (0b0001)

# OR
print("x | y (OR):", x | y)  # Result: 7 (0b0111)

# XOR
print("x ^ y (XOR):", x ^ y)  # Result: 6 (0b0110)

# NOT
print("~x (NOT):", ~x)  # Result: -6 (two's complement)

# Left Shift
print("x << 1 (Left Shift):", x << 1)  # Result: 10 (0b1010)

# Right Shift
print("x >> 1 (Right Shift):", x >> 1)  # Result: 2 (0b0010)
# Out:
# x & y (AND): 1
# x | y (OR): 7
# x ^ y (XOR): 6
# ~x (NOT): -6
# x << 1 (Left Shift): 10
# x >> 1 (Right Shift): 2

# %%
# Membership operators
my_list = [1, 2, 3, 4, 5]

# In operator
print("Is 3 in the list?", 3 in my_list)

# Not in operator
print("Is 10 not in the list?", 10 not in my_list)
# Out:
# Is 3 in the list? True
# Is 10 not in the list? True

# %%
# Identity operators
x = [1, 2, 3]
y = [1, 2, 3]
z = x

# Is operator
print("x is z:", x is z)

# Is not operator
print("x is not y:", x is not y)
# Out:
# x is z: True
# x is not y: True

# %% [markdown]
# - Arithmetic operators for basic math operations,
# - Comparison operators to compare values,
# - Assignment operators for assigning values,
# - Logical operators to combine conditions,
# - Bitwise operators for bit-level operations,
# - Membership operators to check if a value is in a sequence,
# - Identity operators to compare memory addresses.

# %% [markdown]
# # **4-Tokens In Python**

# %% [markdown]
# # What Are Tokens in Python?
# Keywords
# Identifiers
# Literals
# Operators
# Punctuators (Delimiters)

# %%
# Using Python keywords
if True:
    print("This is a keyword example.")
# Out:
# This is a keyword example.

# %%
# Identifiers: variable and function names
name = "Alice"
def greet():
    print("Hello, " + name)

greet()
# Out:
# Hello, Alice

# %%
# Different types of literals
age = 30           # Integer literal
height = 5.9       # Float literal
is_student = False # Boolean literal
name = "Bob"       # String literal

# %%
# Arithmetic and comparison operators
x = 10 + 5   # Addition
y = 3 * 2    # Multiplication
print(x > y) # Comparison (True)
# Out:
# True

# %%
# Punctuators in action
numbers = [1, 2, 3, 4]  # Square brackets (list)
def add(a, b):          # Parentheses and colon (function)
    return a + b
print(add(5, 10))
# Out:
# 15
